# %%
# article = "التقى الدكتور مصطفى مدبولي، رئيس مجلس الوزراء، اليوم، هشام توفيق، وزير قطاع الأعمال العام؛ لمتابعة جهود تطوير صناعة الغزل والنسيج. واستهل رئيس الوزراء اللقاء، بالتأكيد على ضرورة المُضي قدما في إنجاز الخطة الطموحة التي تتبناها الدولة لتطوير صناعة الغزل والنسيج، والاستمرار في جهود تطوير شركات قطاع الأعمال العام، بهدف تنظيمها وفق أنماط حديثة ومتطورة، في إطار توجيهات الرئيس عبد الفتاح السيسي، رئيس الجمهورية، بهذا الشأن، مع أهمية التركيز على تنمية الكوادر العاملة وتأهيل العنصر البشري على استخدام أحدث النظم العالمية. من جانبه، أكد وزير قطاع الأعمال العام أنه يتم حاليا بالفعل مواصلة العمل لتطوير صناعة الغزل والنسيج في مصر، وفق الخطة الطموحة التي يتم تنفيذها لهذا الغرض وتحظى باهتمام كبير من القيادة السياسية، مستعرضا الموقف التنفيذي لمشروع تطوير مصانع الشركة القابضة للقطن والغزل والنسيج والملابس التابعة للوزارة، وخاصة ما يتعلق بالأعمال الإنشائية للمصانع الجديدة أو تحديث المصانع القائمة. وفي هذا السياق، أشار الوزير إلى أنه جار حاليا إتمام كافة الأعمال الإنشائية وفقًا للجدول الزمني المحدد، والتي تشمل العديد من المباني ما بين إنشاءات جديدة وترميم؛ استعدادا لتركيب الماكينات الحديثة الواردة من كبرى الشركات العالمية خلال الفترة المقبلة، على أن يتبع ذلك بدء التشغيل التجريبي لجميع المصانع، تباعا. وخلال عرضه، نوه الوزير إلى موقف إنشاء مصنع غزل (1)، الذي يعد أكبر مصنع للغزل في العالم على مساحة 62.5 ألف متر، وكذا تطوير مصنع غزل (4) بشركة مصر للغزل والنسيج بالمحلة الكبرى على مساحة 24.6 ألف متر، وكذلك تطوير مصنع غزل (6)، على مساحة 17.7 ألف متر، وكذلك الموقف الحالي لمجموعة المصانع الجديدة للنسيج والتحضيرات والصباغة بشركة مصر للغزل والنسيج بالمحلة الكبرى. كما استعرض وزير قطاع الأعمال العام موقف مجمع مصانع شركة مصر صباغي البيضا بكفر الدوار، والوضع الحالي لتطوير شركة دمياط للغزل والنسيج"

# %%
# التقى الدكتور مصطفى مدبولي، رئيس مجلس الوزراء، اليوم، هشام توفيق، وزير قطاع الأعمال العام؛ لمتابعة جهود تطوير صناعة الغزل والنسيج. واستهل رئيس الوزراء اللقاء، بالتأكيد على ضرورة المُضي قدما في إنجاز الخطة الطموحة التي تتبناها الدولة لتطوير صناعة الغزل والنسيج، والاستمرار في جهود تطوير شركات قطاع الأعمال العام، بهدف تنظيمها وفق أنماط حديثة ومتطورة، في إطار توجيهات الرئيس عبد الفتاح السيسي، رئيس الجمهورية، بهذا الشأن، مع أهمية التركيز على تنمية الكوادر العاملة وتأهيل العنصر البشري على استخدام أحدث النظم العالمية. من جانبه، أكد وزير قطاع الأعمال العام أنه يتم حاليا بالفعل مواصلة العمل لتطوير صناعة الغزل والنسيج في مصر، وفق الخطة الطموحة التي يتم تنفيذها لهذا الغرض وتحظى باهتمام كبير من القيادة السياسية، مستعرضا الموقف التنفيذي لمشروع تطوير مصانع الشركة القابضة للقطن والغزل والنسيج والملابس التابعة للوزارة، وخاصة ما يتعلق بالأعمال الإنشائية للمصانع الجديدة أو تحديث المصانع القائمة. وفي هذا السياق، أشار الوزير إلى أنه جار حاليا إتمام كافة الأعمال الإنشائية وفقًا للجدول الزمني المحدد، والتي تشمل العديد من المباني ما بين إنشاءات جديدة وترميم؛ استعدادا لتركيب الماكينات الحديثة الواردة من كبرى الشركات العالمية خلال الفترة المقبلة، على أن يتبع ذلك بدء التشغيل التجريبي لجميع المصانع، تباعا. وخلال عرضه، نوه الوزير إلى موقف إنشاء مصنع غزل (1)، الذي يعد أكبر مصنع للغزل في العالم على مساحة 62.5 ألف متر، وكذا تطوير مصنع غزل (4) بشركة مصر للغزل والنسيج بالمحلة الكبرى على مساحة 24.6 ألف متر، وكذلك تطوير مصنع غزل (6)، على مساحة 17.7 ألف متر، وكذلك الموقف الحالي لمجموعة المصانع الجديدة للنسيج والتحضيرات والصباغة بشركة مصر للغزل والنسيج بالمحلة الكبرى. كما استعرض وزير قطاع الأعمال العام موقف مجمع مصانع شركة مصر صباغي البيضا بكفر الدوار، والوضع الحالي لتطوير شركة دمياط للغزل والنسيج

# %%
import requests

def query(payload, API_URL):
    API_TOKEN = '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'
    headers = {"Authorization": f"Bearer {API_TOKEN}"}
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.json()

def arabicSummerizer(text):
    API_URL = "https://api-inference.huggingface.co/models/Helsinki-NLP/opus-mt-ar-en"
    
    if len(text) > 512:
        text = text[:512]
#     art = art[:512]

    output = query({
      "inputs": text,
    }, API_URL)

    API_URL = "https://api-inference.huggingface.co/models/sshleifer/distilbart-cnn-12-6"
    # headers = {"Authorization": f"Bearer {API_TOKEN}"}

    # def query(payload):
    #   response = requests.post(API_URL, headers=headers, json=payload)
    #   return response.json()

    output = query({
      "inputs": output[0]['translation_text'],
    }, API_URL)

    API_URL = "https://api-inference.huggingface.co/models/Helsinki-NLP/opus-mt-en-ar"
    # headers = {"Authorization": f"Bearer {API_TOKEN}"}

    # def query(payload):
    #   response = requests.post(API_URL, headers=headers, json=payload)
    #   return response.json()

    output = query({
      "inputs": output[0]['summary_text'],
    }, API_URL)

    return output[0]['translation_text']

# %%
# arabicSummerizer(article)

# %%
# art = input('article')

# # art = ' '.join([i for i in art.split() if not i.isdigit()])

# # art = " ".join(art.split())
# # art = art.replace('"', "")
# # art = art.replace("'", "")
# art = art[:512]
# arabicSummerizer(art)

# %%
import os
import json
import random
from flask import Flask, render_template, request

app = Flask(__name__)
# picFloder=os.path.join("static","pics")

# app.config["UPLOAD_FOLDER"]= picFloder

# app.static_folder = 'static'

@app.route("/")
def home():
#     pic1=os.path.join(app.config["UPLOAD_FOLDER"])
#     from datetime import datetime

#     now = datetime.now()

#     current_time = now.strftime("%H:%M:%S")
#     return render_template("summarizer.html",time_bot=str(current_time))
    return render_template("summarizer.html")

@app.route("/get")
def get_bot_response():
    userText = request.args.get('msg')
    word = arabicSummerizer(userText)
    return word

if __name__ == "__main__":
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [12/Dec/2021 22:28:13] "GET / HTTP/1.1" 200 -
# ...
